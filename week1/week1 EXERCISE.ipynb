# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports

import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown,display,update_display

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_DEEPSEEK = 'deepseek-coder-v2'

# %%
# set up environment

ollama_api = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

load_dotenv(override=True)
api_key = os.getenv("OPENAI_API_KEY")
openai = OpenAI()

system_prompt = "You are a tutor specialized in computer programming. Explain the concepts in brief and concise responses. \
Provide a basic example. Return in Markdown format."

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
# Get gpt-4o-mini to answer, with streaming

stream = openai.chat.completions.create(
    model=MODEL_GPT,
    messages=[
        {"role": "system", "content": system_prompt },
        {"role": "user", "content": question },
    ],
    stream=True
)

response = ""
display_handle = display(Markdown(""), display_id=True)

for chunk in stream:
    response += chunk.choices[0].delta.content or ''
    response = response.replace("```","").replace("markdown", "")
    update_display(Markdown(response), display_id=display_handle.display_id)
# Out:
# The provided code snippet uses a generator expression with the `yield from` syntax to yield values one by one from a set comprehension. Let's break it down:
#
# ### Concepts
#
# 1. **Generator**: A type of iterable that generates values on the fly and can be paused and resumed.
#
# 2. **`yield from`**: A way to yield multiple values from an iterable (like a list or set) in one go, allowing for cleaner and more readable code.
#
# 3. **Set Comprehension**: A concise way to create a set in Python by defining a set of unique values based on some iterable.
#
# ### Explanation of the Code
#
# - `{book.get("author") for book in books if book.get("author")}`: This part is a set comprehension that iterates over a collection named `books`. For each `book`, it retrieves the value associated with the key "author". If the author exists (i.e., is not `None` or an empty string), it adds that author to a set (ensuring uniqueness).
#
# ...

# %%
# Get Llama 3.2 to answer

# %%
stream = ollama_api.chat.completions.create(
    model=MODEL_DEEPSEEK,
    messages=[
        {"role": "system", "content": system_prompt },
        {"role": "user", "content": question },
    ],
    stream=True
)

response = ""
display_handle = display(Markdown(""), display_id=True)

for chunk in stream:
    response += chunk.choices[0].delta.content or ''
    response = response.replace("```","").replace("markdown", "")
    update_display(Markdown(response), display_id=display_handle.display_id)
# Out:
#  This line of code is using Python's `yield from` syntax to generate a sequence of author names from a list of dictionaries, where each dictionary represents a book with an "author" key.
#
# ### Why it works:
# - **`yield from`**: This combines the functionality of `yield` (to produce a value) and `from_iterable` (to yield values from another iterable).
# - **`{book.get("author") for book in books if book.get("author")}`**:
#   - **Set comprehension**: It generates a set containing all the "author" values from the dictionaries where an author exists (`if book.get("author")`).
#   - **Generator expression**: The `yield from` is used here to yield each element of this set one by one, effectively flattening it into a sequence that can be iterated over.
#
# ### Basic Example:
# Let's say you have a list of dictionaries where each dictionary represents a book with an "author" key:
#
# python
# books = [
#     {"title": "1984", "author": "George Orwell"},
# ...
